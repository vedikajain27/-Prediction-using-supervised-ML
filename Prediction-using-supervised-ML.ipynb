# %% [markdown]
# **The Sparks Foundation (Graduate Rotational Internship Program)**
# Data Science and Business Analytics
#
# Task 1: Prediction Using Supervised ML Predict the percentage of an student bassed on the no. of hours. This is a simplest Linear Regression as it involves 2 variables. What will be predicted score if a student studies for 9.25 hrs/day ? (Level: Beginner)
#
# Linear Regression: Linear regression attempts to model the relationship between two variables by fitting a linear equation to observed data. One variable is considered to be an explanatory variable, and the other is considered to be a dependent variable. The case of one explanatory variable is called simple linear regression; for more than one, the process is called multiple linear regression. The above task is example of simple linear regression as it involves 2 variables they are hours of study and score of students.
#
# Language: Python 3 IDE: Jupyter Notebook Author: Vedika Jain

# %% [markdown]
# **Step 1: Importing and Reading Dataset**

# %%
#Importing required libraries:

import pandas as pd, numpy as np, matplotlib.pyplot as plt  
# %matplotlib inline

# %%
#Reading given data:

url = "http://bit.ly/w-data"
data = pd.read_csv(url)
print("***Data imported successfully***")

data
# Out:
# ***Data imported successfully***
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
data.shape
# Out:
# (25, 2)

# %%
data.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %%
data.isnull().sum()
# Out:
# Hours     0
# Scores    0
# dtype: int64

# %% [markdown]
# **Step 2: Visualization and Analyzation of Dataset**

# %% [markdown]
# In these step we are going to visualize above dataset in 2D graph and from those graph analyze relation between it's variable.#

# %%
#Ploting of distribution of scores and numbers of hours of study on 2D graph:
data.plot(x='Hours', y='Scores', style='ro')  
plt.title('No. of Hours Studies vs Scores of Student')  
plt.xlabel('No. of Hours Studied')  
plt.ylabel('Scores')  
plt.show()

# %% [markdown]
# **Step 3: Preparation of dataset**

# %% [markdown]
# The next step is to split them into input (independent) variables i.e., "attributes" and output (dependent) variable i.e, "labels".#

# %%
# No. of Hours Studied  = X varible
# Scores  = Y variable
X = data.iloc[:, :-1].values  
Y = data.iloc[:, 1].values

# %%
# View X varible: No. of Hours Studied Student
X
# Out:
# array([[2.5],
#        [5.1],
#        [3.2],
#        [8.5],
#        [3.5],
#        [1.5],
#        [9.2],
#        [5.5],
#        [8.3],
#        [2.7],
#        [7.7],
#        [5.9],
#        [4.5],
#        [3.3],
#        [1.1],
#        [8.9],
#        [2.5],
#        [1.9],
#        [6.1],
#        [7.4],
#        [2.7],
#        [4.8],
#        [3.8],
#        [6.9],
#        [7.8]])

# %%
# View Y variable: Scores of Student
Y
# Out:
# array([21, 47, 27, 75, 30, 20, 88, 60, 81, 25, 85, 62, 41, 42, 17, 95, 30,
#        24, 67, 69, 30, 54, 35, 76, 86])

# %%
#Now we get our attributes and labels, the next step is to split this data into training and test sets. 
#We'll do this by using Scikit-Learn's built-in train_test_split() method:

from sklearn.model_selection import train_test_split  
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
X_train
# Out:
# array([[3.8],
#        [1.9],
#        [7.8],
#        [6.9],
#        [1.1],
#        [5.1],
#        [7.7],
#        [3.3],
#        [8.3],
#        [9.2],
#        [6.1],
#        [3.5],
#        [2.7],
#        [5.5],
#        [2.7],
#        [8.5],
#        [2.5],
#        [4.8],
#        [8.9],
#        [4.5]])

# %%
X_test
# Out:
# array([[1.5],
#        [3.2],
#        [7.4],
#        [2.5],
#        [5.9]])

# %%
Y_train
# Out:
# array([35, 24, 86, 76, 17, 47, 85, 42, 81, 88, 67, 30, 25, 60, 30, 75, 21,
#        54, 95, 41])

# %%
Y_test
# Out:
# array([20, 27, 69, 30, 62])

# %% [markdown]
# **Step 4: Training of Machine Learning Model (Algorithm)**
#
# We have split our data into training and testing sets, and now we are to train our Machine Learning Model (Algorithm).#

# %%
from sklearn.linear_model import LinearRegression  
regressor = LinearRegression()  
regressor.fit(X_train, Y_train) 

print(" *** Training of ML Model is Completed !!! *** ")
# Out:
#  *** Training of ML Model is Completed !!! ***

# %% [markdown]
# **Step 5: Visualize the Model**
#
# Now, In these step visualize the trained model.

# %%
# Plotting the regression line
line = regressor.coef_ * X + regressor.intercept_

# Plotting for the test data
plt.scatter(X, Y)
plt.plot(X, line, color = "red");
plt.show()

# %% [markdown]
# **Step 6: Making Predictions**
#
# Now we got trained Machine Learning Model (Algorithm), So it's time to make some predictions about above dataset.

# %%
print(X_test) # Testing data - In Hours
Y_pred = regressor.predict(X_test) # Predicting the scores
# Out:
# [[1.5]
#  [3.2]
#  [7.4]
#  [2.5]
#  [5.9]]

# %%
# Comparing Actual vs Predicted data
df = pd.DataFrame({'Actual': Y_test, 'Predicted': Y_pred})  
df
# Out:
#    Actual  Predicted
# 0      20  16.884145
# 1      27  33.732261
# 2      69  75.357018
# 3      30  26.794801
# 4      62  60.491033

# %%
# Testing with our own custom data
# score of student if he/she studies for 9.25 hrs/day

hours = 9.25
own_pred = regressor.predict([[hours]])
print("No of Hours = {}".format(hours))
print("Predicted Score = {}".format(own_pred[0]))
# Out:
# No of Hours = 9.25
# Predicted Score = 93.69173248737539

# %% [markdown]
# **Step 7: Evaluating the model**
#
# The final step is to evaluate the performance of algorithm. This step is particularly important to compare how well different algorithms perform on a particular dataset. For simplicity here, we have chosen the mean square error. There are many such metrics.#

# %%
# Mean Absolute Error:

from sklearn import metrics  
print('Mean Absolute Error:', metrics.mean_absolute_error(Y_test, Y_pred)) 

# Max Error:
print('Max Error:', metrics.max_error(Y_test, Y_pred))

# Mean Squared Error:
print('Mean Squared Error:', metrics.mean_squared_error(Y_test, Y_pred))
# Out:
# Mean Absolute Error: 4.183859899002982
# Max Error: 6.732260779489835
# Mean Squared Error: 21.598769307217456
